# %%
# 데이터 다운로드
# !wget https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip

import zipfile

with zipfile.ZipFile('/content/drive/MyDrive/Git/tensorflow2-colab-ex/resources/img/cats_and_dogs_filtered.zip', 'r') as target_file:
  target_file.extractall('/content/drive/MyDrive/Git/tensorflow2-colab-ex/resources/img/')
# Out:
# --2023-03-29 10:48:04--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.62.128, 172.253.122.128, 142.251.163.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.62.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘cats_and_dogs_filtered.zip.2’
#
# cats_and_dogs_filte 100%[===================>]  65.43M   134MB/s    in 0.5s
#
# 2023-03-29 10:48:04 (134 MB/s) - ‘cats_and_dogs_filtered.zip.2’ saved [68606236/68606236]

# %%
# 폴더 삭제

import os 
import shutil

path = '/content/cats_and_dogs_filtered/'
if os.path.exists(path):
  shutil.rmtree(path)
  print(path, 'is removed !!!')
# Out:
# /content/cats_and_dogs_filtered/ is removed !!!
