# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Git
# Out:
# /content/drive/MyDrive/Git

# %%
# !git clone https://EoneTrance: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@github.com/EoneTrance/tensorflow2-colab-ex.git
# Out:
# Cloning into 'tensorflow2-colab-ex'...
# ...

# %%
cd ./tensorflow2-colab-ex
# Out:
# /content/drive/MyDrive/Git/tensorflow2-colab-ex

# %%
# !git config --global user.email "karnenis@gmail.com"
# !git config --global user.name "EoneTrance"

# %%
# !echo "# tensorflow2-colab-ex" >> README.md

# %%
# !git add README.md

# %%
# !git commit -m "init"
# Out:
# [master (root-commit) ee073c0] init
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/EoneTrance/tensorflow2-colab-ex.git/'

# %%
cd /content/drive/MyDrive/Git/tensorflow2-colab-ex/
# Out:
# /content/drive/MyDrive/Git/tensorflow2-colab-ex

# %%
# !git add .

# %%
# !git config --global user.email "karnenis@gmail.com"
# !git config --global user.name "EoneTrance"

# %%
# !git commit -m "simple_rnn"
# Out:
# [main 6a416d4] simple_rnn
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push --set-upstream origin main
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/EoneTrance/tensorflow2-colab-ex.git/'

# %%
# !git remote remove origin

# %%
# !git remote add origin https://EoneTrance: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@github.com/EoneTrance/tensorflow2-colab-ex.git
